# %% [markdown]
# # Dune Data Quality
#
# Validate cached Dune exports, protocol/version mappings, and result shapes.

# %%
from pathlib import Path
import polars as pl

processed = Path("../data/processed")
protocols = pl.read_parquet(processed / "protocol_volumes.parquet")
versions = pl.read_parquet(processed / "protocol_version_breakdown.parquet")
protocols, versions.head(20)

# %%
protocols.select(
    pl.col("volume_7d_usd").sum().alias("total_7d"),
    pl.col("volume_30d_usd").sum().alias("total_30d"),
    pl.col("share_7d").sum().alias("share_7d_sum"),
    pl.col("share_30d").sum().alias("share_30d_sum"),
)

# %% [markdown]
# ## All-Venue Interpretation
#
# The protocol comparison dashboard is scoped to selected protocols. The all-venue export compares the current Tycho target set against every Ethereum `dex.trades` venue row for the target-token universe. Aggregator/orderflow tables are analyzed separately because they are not the same as underlying pool liquidity.

# %%
all_venue = pl.read_parquet(processed / "all_venue_coverage.parquet")
non_tycho = pl.read_parquet(processed / "non_tycho_venue_breakdown.parquet")
aggregators = pl.read_parquet(processed / "aggregator_orderflow_breakdown.parquet")
all_venue

# %%
non_tycho.head(25)

# %%
aggregators.head(25)
